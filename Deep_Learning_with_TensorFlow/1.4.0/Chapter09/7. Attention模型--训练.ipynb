# %%
import tensorflow as tf

# %% [markdown]
# #### 1.参数设置。

# %%
# 假设输入数据已经用9.2.1小节中的方法转换成了单词编号的格式。
SRC_TRAIN_DATA = "./train.en"          # 源语言输入文件。
TRG_TRAIN_DATA = "./train.zh"          # 目标语言输入文件。
CHECKPOINT_PATH = "./attention_ckpt"   # checkpoint保存路径。  

HIDDEN_SIZE = 1024                     # LSTM的隐藏层规模。
DECODER_LAYERS = 2                     # 解码器中LSTM结构的层数。这个例子中编码器固定使用单层的双向LSTM。
SRC_VOCAB_SIZE = 10000                 # 源语言词汇表大小。
TRG_VOCAB_SIZE = 4000                  # 目标语言词汇表大小。
BATCH_SIZE = 100                       # 训练数据batch的大小。
NUM_EPOCH = 5                          # 使用训练数据的轮数。
KEEP_PROB = 0.8                        # 节点不被dropout的概率。
MAX_GRAD_NORM = 5                      # 用于控制梯度膨胀的梯度大小上限。
SHARE_EMB_AND_SOFTMAX = True           # 在Softmax层和词向量层之间共享参数。

MAX_LEN = 50   # 限定句子的最大单词数量。
SOS_ID  = 1    # 目标语言词汇表中<sos>的ID。

# %% [markdown]
# #### 2.读取训练数据并创建Dataset。

# %%
# 使用Dataset从一个文件中读取一个语言的数据。
# 数据的格式为每行一句话，单词已经转化为单词编号。
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # 根据空格将单词编号切分开并放入一个一维向量。
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # 将字符串形式的单词编号转化为整数。
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # 统计每个句子的单词数量，并与句子内容一起放入Dataset中。
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

# 从源语言文件src_path和目标语言文件trg_path中分别读取数据，并进行填充和
# batching操作。
def MakeSrcTrgDataset(src_path, trg_path, batch_size):
    # 首先分别读取源语言数据和目标语言数据。
    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    # 通过zip操作将两个Dataset合并为一个Dataset。现在每个Dataset中每一项数据ds
    # 由4个张量组成：
    #   ds[0][0]是源句子
    #   ds[0][1]是源句子长度
    #   ds[1][0]是目标句子
    #   ds[1][1]是目标句子长度
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # 删除内容为空（只包含<EOS>）的句子和长度过长的句子。
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    # 从图9-5可知，解码器需要两种格式的目标句子：
    #   1.解码器的输入(trg_input)，形式如同"<sos> X Y Z"
    #   2.解码器的目标输出(trg_label)，形式如同"X Y Z <eos>"
    # 上面从文件中读到的目标句子是"X Y Z <eos>"的形式，我们需要从中生成"<sos> X Y Z"
    # 形式并加入到Dataset中。
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    dataset = dataset.map(MakeTrgInput)

    # 随机打乱训练数据。
    dataset = dataset.shuffle(10000)

    # 规定填充后输出的数据维度。
    padded_shapes = (
        (tf.TensorShape([None]),      # 源句子是长度未知的向量
         tf.TensorShape([])),         # 源句子长度是单个数字
        (tf.TensorShape([None]),      # 目标句子（解码器输入）是长度未知的向量
         tf.TensorShape([None]),      # 目标句子（解码器目标输出）是长度未知的向量
         tf.TensorShape([])))         # 目标句子长度是单个数字
    # 调用padded_batch方法进行batching操作。
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# #### 3.定义翻译模型。

# %%
# 定义NMTModel类来描述模型。
class NMTModel(object):
    # 在模型的初始化函数中定义模型要用到的变量。
    def __init__(self):
        # 定义编码器和解码器所使用的LSTM结构。
        self.enc_cell_fw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
        self.enc_cell_bw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
        self.dec_cell = tf.nn.rnn_cell.MultiRNNCell(
          [tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE) 
           for _ in range(DECODER_LAYERS)])

        # 为源语言和目标语言分别定义词向量。   
        self.src_embedding = tf.get_variable(
            "src_emb", [SRC_VOCAB_SIZE, HIDDEN_SIZE])
        self.trg_embedding = tf.get_variable(
            "trg_emb", [TRG_VOCAB_SIZE, HIDDEN_SIZE])

        # 定义softmax层的变量
        if SHARE_EMB_AND_SOFTMAX:
           self.softmax_weight = tf.transpose(self.trg_embedding)
        else:
           self.softmax_weight = tf.get_variable(
               "weight", [HIDDEN_SIZE, TRG_VOCAB_SIZE])
        self.softmax_bias = tf.get_variable(
            "softmax_bias", [TRG_VOCAB_SIZE])

    # 在forward函数中定义模型的前向计算图。
    # src_input, src_size, trg_input, trg_label, trg_size分别是上面
    # MakeSrcTrgDataset函数产生的五种张量。
    def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
        batch_size = tf.shape(src_input)[0]
    
        # 将输入和输出单词编号转为词向量。
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)
        
        # 在词向量上进行dropout。
        src_emb = tf.nn.dropout(src_emb, KEEP_PROB)
        trg_emb = tf.nn.dropout(trg_emb, KEEP_PROB)

        # 使用dynamic_rnn构造编码器。
        # 编码器读取源句子每个位置的词向量，输出最后一步的隐藏状态enc_state。
        # 因为编码器是一个双层LSTM，因此enc_state是一个包含两个LSTMStateTuple类
        # 张量的tuple，每个LSTMStateTuple对应编码器中的一层。
        # 张量的维度是 [batch_size, HIDDEN_SIZE]。
        # enc_outputs是顶层LSTM在每一步的输出，它的维度是[batch_size, 
        # max_time, HIDDEN_SIZE]。Seq2Seq模型中不需要用到enc_outputs，而
        # 后面介绍的attention模型会用到它。
        # 下面的代码取代了Seq2Seq样例代码中forward函数里的相应部分。
        with tf.variable_scope("encoder"):
            # 构造编码器时，使用bidirectional_dynamic_rnn构造双向循环网络。
            # 双向循环网络的顶层输出enc_outputs是一个包含两个张量的tuple，每个张量的
            # 维度都是[batch_size, max_time, HIDDEN_SIZE]，代表两个LSTM在每一步的输出。
            enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(
                self.enc_cell_fw, self.enc_cell_bw, src_emb, src_size, 
                dtype=tf.float32)
            # 将两个LSTM的输出拼接为一个张量。
            enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)     

        with tf.variable_scope("decoder"):
            # 选择注意力权重的计算模型。BahdanauAttention是使用一个隐藏层的前馈神经网络。
            # memory_sequence_length是一个维度为[batch_size]的张量，代表batch
            # 中每个句子的长度，Attention需要根据这个信息把填充位置的注意力权重设置为0。
            attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                HIDDEN_SIZE, enc_outputs,
                memory_sequence_length=src_size)

            # 将解码器的循环神经网络self.dec_cell和注意力一起封装成更高层的循环神经网络。
            attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                self.dec_cell, attention_mechanism,
                attention_layer_size=HIDDEN_SIZE)

            # 使用attention_cell和dynamic_rnn构造编码器。
            # 这里没有指定init_state，也就是没有使用编码器的输出来初始化输入，而完全依赖
            # 注意力作为信息来源。
            dec_outputs, _ = tf.nn.dynamic_rnn(
                attention_cell, trg_emb, trg_size, dtype=tf.float32)

        # 计算解码器每一步的log perplexity。这一步与语言模型代码相同。
        output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
        logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
        loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=tf.reshape(trg_label, [-1]), logits=logits)

        # 在计算平均损失时，需要将填充位置的权重设置为0，以避免无效位置的预测干扰
        # 模型的训练。
        label_weights = tf.sequence_mask(
            trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
        label_weights = tf.reshape(label_weights, [-1])
        cost = tf.reduce_sum(loss * label_weights)
        cost_per_token = cost / tf.reduce_sum(label_weights)
        
        # 定义反向传播操作。反向操作的实现与语言模型代码相同。
        trainable_variables = tf.trainable_variables()

        # 控制梯度大小，定义优化方法和训练步骤。
        grads = tf.gradients(cost / tf.to_float(batch_size),
                             trainable_variables)
        grads, _ = tf.clip_by_global_norm(grads, MAX_GRAD_NORM)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0)
        train_op = optimizer.apply_gradients(
            zip(grads, trainable_variables))
        return cost_per_token, train_op

# %% [markdown]
# #### 4.训练过程和主函数。

# %%
# 使用给定的模型model上训练一个epoch，并返回全局步数。
# 每训练200步便保存一个checkpoint。
def run_epoch(session, cost_op, train_op, saver, step):
    # 训练一个epoch。
    # 重复训练步骤直至遍历完Dataset中所有数据。
    while True:
        try:
            # 运行train_op并计算损失值。训练数据在main()函数中以Dataset方式提供。
            cost, _ = session.run([cost_op, train_op])
            if step % 10 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # 每200步保存一个checkpoint。
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

def main():
    # 定义初始化函数。
    initializer = tf.random_uniform_initializer(-0.05, 0.05)

    # 定义训练用的循环神经网络模型。
    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel()
  
    # 定义输入数据。
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # 定义前向计算图。输入数据以张量形式提供给forward函数。
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # 训练模型。
    saver = tf.train.Saver()
    step = 0
    with tf.Session() as sess:
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            print("In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
if __name__ == "__main__":
    main()
# Out:
# In iteration: 1
# After 0 steps, per token cost is 8.295
# After 10 steps, per token cost is 7.945
# After 20 steps, per token cost is 8.142
# After 30 steps, per token cost is 15.050
# After 40 steps, per token cost is 7.863
# After 50 steps, per token cost is 8.620
# After 60 steps, per token cost is 7.815
# After 70 steps, per token cost is 7.219
# After 80 steps, per token cost is 8.901
# After 90 steps, per token cost is 6.968
# After 100 steps, per token cost is 7.139
# After 110 steps, per token cost is 8.055
# After 120 steps, per token cost is 6.848
# After 130 steps, per token cost is 6.553
# After 140 steps, per token cost is 6.907
# After 150 steps, per token cost is 7.228
# After 160 steps, per token cost is 6.710
# After 170 steps, per token cost is 16.085
# After 180 steps, per token cost is 6.645
# After 190 steps, per token cost is 6.441
# After 200 steps, per token cost is 6.624
# After 210 steps, per token cost is 6.543
# After 220 steps, per token cost is 10.019
# After 230 steps, per token cost is 8.243
# After 240 steps, per token cost is 7.318
# After 250 steps, per token cost is 6.478
# After 260 steps, per token cost is 7.669
# After 270 steps, per token cost is 6.699
# After 280 steps, per token cost is 6.789
# After 290 steps, per token cost is 9.346
# After 300 steps, per token cost is 6.780
# After 310 steps, per token cost is 6.586
# After 320 steps, per token cost is 6.486
# After 330 steps, per token cost is 8.433
# After 340 steps, per token cost is 6.413
# After 350 steps, per token cost is 27.557
# After 360 steps, per token cost is 6.356
# After 370 steps, per token cost is 6.275
# After 380 steps, per token cost is 9.101
# After 390 steps, per token cost is 6.569
# After 400 steps, per token cost is 6.250
# After 410 steps, per token cost is 7.920
# After 420 steps, per token cost is 11.671
# After 430 steps, per token cost is 6.192
# After 440 steps, per token cost is 6.079
# After 450 steps, per token cost is 6.030
# After 460 steps, per token cost is 8.814
# After 470 steps, per token cost is 6.325
# After 480 steps, per token cost is 6.194
# After 490 steps, per token cost is 6.037
# After 500 steps, per token cost is 5.929
# After 510 steps, per token cost is 5.970
# After 520 steps, per token cost is 6.259
# After 530 steps, per token cost is 6.016
# After 540 steps, per token cost is 6.271
# After 550 steps, per token cost is 6.343
# After 560 steps, per token cost is 6.023
# After 570 steps, per token cost is 5.927
# After 580 steps, per token cost is 5.989
# After 590 steps, per token cost is 5.705
# After 600 steps, per token cost is 5.866
# After 610 steps, per token cost is 5.735
# After 620 steps, per token cost is 5.748
# After 630 steps, per token cost is 5.583
# After 640 steps, per token cost is 5.479
# After 650 steps, per token cost is 5.613
# After 660 steps, per token cost is 5.654
# After 670 steps, per token cost is 5.643
# After 680 steps, per token cost is 5.608
# After 690 steps, per token cost is 5.720
# After 700 steps, per token cost is 5.513
# After 710 steps, per token cost is 5.329
# After 720 steps, per token cost is 5.483
# After 730 steps, per token cost is 5.390
# After 740 steps, per token cost is 5.237
# After 750 steps, per token cost is 5.446
# After 760 steps, per token cost is 5.261
# After 770 steps, per token cost is 5.387
# After 780 steps, per token cost is 5.220
# After 790 steps, per token cost is 5.192
# After 800 steps, per token cost is 5.216
# After 810 steps, per token cost is 5.184
# After 820 steps, per token cost is 5.167
# After 830 steps, per token cost is 5.154
# After 840 steps, per token cost is 5.116
# After 850 steps, per token cost is 5.269
# After 860 steps, per token cost is 5.039
# After 870 steps, per token cost is 5.032
# After 880 steps, per token cost is 4.914
# After 890 steps, per token cost is 5.071
# After 900 steps, per token cost is 5.005
# After 910 steps, per token cost is 4.932
# After 920 steps, per token cost is 4.947
# After 930 steps, per token cost is 4.992
# After 940 steps, per token cost is 4.935
# After 950 steps, per token cost is 4.914
# After 960 steps, per token cost is 4.844
# After 970 steps, per token cost is 4.811
# After 980 steps, per token cost is 4.761
# After 990 steps, per token cost is 4.717
# After 1000 steps, per token cost is 4.777
# After 1010 steps, per token cost is 4.778
# After 1020 steps, per token cost is 4.689
# After 1030 steps, per token cost is 4.837
# After 1040 steps, per token cost is 4.763
# After 1050 steps, per token cost is 4.850
# After 1060 steps, per token cost is 4.757
# After 1070 steps, per token cost is 4.554
# After 1080 steps, per token cost is 4.543
# After 1090 steps, per token cost is 4.495
# After 1100 steps, per token cost is 4.524
# After 1110 steps, per token cost is 4.697
# After 1120 steps, per token cost is 4.520
# After 1130 steps, per token cost is 4.619
# After 1140 steps, per token cost is 4.592
# After 1150 steps, per token cost is 4.618
# After 1160 steps, per token cost is 4.616
# After 1170 steps, per token cost is 4.587
# After 1180 steps, per token cost is 4.590
# After 1190 steps, per token cost is 4.482
# After 1200 steps, per token cost is 4.273
# After 1210 steps, per token cost is 4.478
# After 1220 steps, per token cost is 4.513
# After 1230 steps, per token cost is 4.419
# After 1240 steps, per token cost is 4.359
# After 1250 steps, per token cost is 4.356
# After 1260 steps, per token cost is 4.412
# After 1270 steps, per token cost is 4.334
# After 1280 steps, per token cost is 4.338
# After 1290 steps, per token cost is 4.467
# After 1300 steps, per token cost is 4.421
# After 1310 steps, per token cost is 4.186
# After 1320 steps, per token cost is 4.416
# After 1330 steps, per token cost is 4.303
# After 1340 steps, per token cost is 4.251
# After 1350 steps, per token cost is 4.245
# After 1360 steps, per token cost is 4.228
# After 1370 steps, per token cost is 4.332
# After 1380 steps, per token cost is 4.320
# After 1390 steps, per token cost is 4.369
# After 1400 steps, per token cost is 4.206
# After 1410 steps, per token cost is 4.184
# After 1420 steps, per token cost is 4.188
# After 1430 steps, per token cost is 4.259
# After 1440 steps, per token cost is 4.406
# After 1450 steps, per token cost is 4.167
# After 1460 steps, per token cost is 4.134
# After 1470 steps, per token cost is 4.236
# After 1480 steps, per token cost is 4.183
# After 1490 steps, per token cost is 4.206
# After 1500 steps, per token cost is 4.317
# After 1510 steps, per token cost is 4.131
# After 1520 steps, per token cost is 4.299
# After 1530 steps, per token cost is 4.148
# After 1540 steps, per token cost is 4.031
# After 1550 steps, per token cost is 4.184
# After 1560 steps, per token cost is 4.288
# After 1570 steps, per token cost is 4.066
# After 1580 steps, per token cost is 4.013
# After 1590 steps, per token cost is 4.137
# After 1600 steps, per token cost is 4.073
# After 1610 steps, per token cost is 4.276
# After 1620 steps, per token cost is 4.047
# After 1630 steps, per token cost is 4.015
# After 1640 steps, per token cost is 3.907
# After 1650 steps, per token cost is 4.092
# After 1660 steps, per token cost is 4.105
# After 1670 steps, per token cost is 3.958
# After 1680 steps, per token cost is 4.128
# After 1690 steps, per token cost is 4.097
# After 1700 steps, per token cost is 4.008
# After 1710 steps, per token cost is 3.982
# After 1720 steps, per token cost is 4.061
# After 1730 steps, per token cost is 4.069
# After 1740 steps, per token cost is 3.980
# After 1750 steps, per token cost is 4.003
# After 1760 steps, per token cost is 3.931
# After 1770 steps, per token cost is 3.938
# After 1780 steps, per token cost is 3.863
# After 1790 steps, per token cost is 3.947
# After 1800 steps, per token cost is 3.958
# In iteration: 2
# After 1810 steps, per token cost is 4.055
# After 1820 steps, per token cost is 3.995
# After 1830 steps, per token cost is 3.845
# After 1840 steps, per token cost is 3.992
# After 1850 steps, per token cost is 3.975
# After 1860 steps, per token cost is 3.921
# After 1870 steps, per token cost is 3.828
# After 1880 steps, per token cost is 3.929
# After 1890 steps, per token cost is 4.017
# After 1900 steps, per token cost is 4.073
# After 1910 steps, per token cost is 3.863
# After 1920 steps, per token cost is 4.110
# After 1930 steps, per token cost is 3.917
# After 1940 steps, per token cost is 3.938
# After 1950 steps, per token cost is 3.873
# After 1960 steps, per token cost is 3.863
# After 1970 steps, per token cost is 3.932
# After 1980 steps, per token cost is 3.874
# After 1990 steps, per token cost is 3.793
# After 2000 steps, per token cost is 3.909
# After 2010 steps, per token cost is 3.766
# After 2020 steps, per token cost is 3.726
# After 2030 steps, per token cost is 3.650
# After 2040 steps, per token cost is 3.798
# After 2050 steps, per token cost is 3.759
# After 2060 steps, per token cost is 3.827
# After 2070 steps, per token cost is 3.808
# After 2080 steps, per token cost is 3.729
# After 2090 steps, per token cost is 3.983
# After 2100 steps, per token cost is 3.907
# After 2110 steps, per token cost is 3.874
# After 2120 steps, per token cost is 3.712
# After 2130 steps, per token cost is 3.943
# After 2140 steps, per token cost is 3.641
# After 2150 steps, per token cost is 3.795
# After 2160 steps, per token cost is 3.721
# After 2170 steps, per token cost is 3.827
# After 2180 steps, per token cost is 3.642
# After 2190 steps, per token cost is 3.720
# After 2200 steps, per token cost is 3.872
# After 2210 steps, per token cost is 3.840
# After 2220 steps, per token cost is 3.722
# After 2230 steps, per token cost is 3.729
# After 2240 steps, per token cost is 3.757
# After 2250 steps, per token cost is 3.760
# After 2260 steps, per token cost is 3.700
# After 2270 steps, per token cost is 3.694
# After 2280 steps, per token cost is 3.833
# After 2290 steps, per token cost is 3.606
# After 2300 steps, per token cost is 3.611
# After 2310 steps, per token cost is 3.627
# After 2320 steps, per token cost is 3.576
# After 2330 steps, per token cost is 3.730
# After 2340 steps, per token cost is 3.791
# After 2350 steps, per token cost is 3.652
# After 2360 steps, per token cost is 3.763
# After 2370 steps, per token cost is 3.765
# After 2380 steps, per token cost is 3.815
# After 2390 steps, per token cost is 3.636
# After 2400 steps, per token cost is 3.512
# After 2410 steps, per token cost is 3.647
# After 2420 steps, per token cost is 3.541
# After 2430 steps, per token cost is 3.626
# After 2440 steps, per token cost is 3.743
# After 2450 steps, per token cost is 3.667
# After 2460 steps, per token cost is 3.719
# After 2470 steps, per token cost is 3.564
# After 2480 steps, per token cost is 3.709
# After 2490 steps, per token cost is 3.692
# After 2500 steps, per token cost is 3.773
# After 2510 steps, per token cost is 3.648
# After 2520 steps, per token cost is 3.598
# After 2530 steps, per token cost is 3.737
# After 2540 steps, per token cost is 3.707
# After 2550 steps, per token cost is 3.643
# After 2560 steps, per token cost is 3.686
# After 2570 steps, per token cost is 3.652
# After 2580 steps, per token cost is 3.670
# After 2590 steps, per token cost is 3.699
# After 2600 steps, per token cost is 3.572
# After 2610 steps, per token cost is 3.633
# After 2620 steps, per token cost is 3.572
# After 2630 steps, per token cost is 3.553
# After 2640 steps, per token cost is 3.685
# After 2650 steps, per token cost is 3.286
# After 2660 steps, per token cost is 3.516
# After 2670 steps, per token cost is 3.632
# After 2680 steps, per token cost is 3.449
# After 2690 steps, per token cost is 3.692
# After 2700 steps, per token cost is 3.445
# After 2710 steps, per token cost is 3.619
# After 2720 steps, per token cost is 3.618
# After 2730 steps, per token cost is 3.596
# After 2740 steps, per token cost is 3.639
# After 2750 steps, per token cost is 3.720
# After 2760 steps, per token cost is 3.388
# After 2770 steps, per token cost is 3.413
# After 2780 steps, per token cost is 3.476
# After 2790 steps, per token cost is 3.560
# After 2800 steps, per token cost is 3.439
# After 2810 steps, per token cost is 3.706
# After 2820 steps, per token cost is 3.483
# After 2830 steps, per token cost is 3.422
# After 2840 steps, per token cost is 3.291
# After 2850 steps, per token cost is 3.443
# After 2860 steps, per token cost is 3.436
# After 2870 steps, per token cost is 3.542
# After 2880 steps, per token cost is 3.521
# After 2890 steps, per token cost is 3.481
# After 2900 steps, per token cost is 3.509
# After 2910 steps, per token cost is 3.740
# After 2920 steps, per token cost is 3.525
# After 2930 steps, per token cost is 3.477
# After 2940 steps, per token cost is 3.529
# After 2950 steps, per token cost is 3.707
# After 2960 steps, per token cost is 3.555
# After 2970 steps, per token cost is 3.498
# After 2980 steps, per token cost is 3.560
# After 2990 steps, per token cost is 3.462
# After 3000 steps, per token cost is 3.278
# After 3010 steps, per token cost is 3.647
# After 3020 steps, per token cost is 3.672
# After 3030 steps, per token cost is 3.422
# After 3040 steps, per token cost is 3.524
# After 3050 steps, per token cost is 3.434
# After 3060 steps, per token cost is 3.546
# After 3070 steps, per token cost is 3.503
# After 3080 steps, per token cost is 3.374
# After 3090 steps, per token cost is 3.514
# After 3100 steps, per token cost is 3.343
# After 3110 steps, per token cost is 3.354
# After 3120 steps, per token cost is 3.370
# After 3130 steps, per token cost is 3.446
# After 3140 steps, per token cost is 3.401
# After 3150 steps, per token cost is 3.375
# After 3160 steps, per token cost is 3.362
# After 3170 steps, per token cost is 3.428
# After 3180 steps, per token cost is 3.439
# After 3190 steps, per token cost is 3.386
# After 3200 steps, per token cost is 3.403
# After 3210 steps, per token cost is 3.376
# After 3220 steps, per token cost is 3.374
# After 3230 steps, per token cost is 3.465
# After 3240 steps, per token cost is 3.417
# After 3250 steps, per token cost is 3.331
# After 3260 steps, per token cost is 3.364
# After 3270 steps, per token cost is 3.381
# After 3280 steps, per token cost is 3.349
# After 3290 steps, per token cost is 3.343
# After 3300 steps, per token cost is 3.367
# After 3310 steps, per token cost is 3.429
# After 3320 steps, per token cost is 3.272
# After 3330 steps, per token cost is 3.309
# After 3340 steps, per token cost is 3.438
# After 3350 steps, per token cost is 3.531
# After 3360 steps, per token cost is 3.282
# After 3370 steps, per token cost is 3.266
# After 3380 steps, per token cost is 3.527
# After 3390 steps, per token cost is 3.407
# After 3400 steps, per token cost is 3.104
# After 3410 steps, per token cost is 3.432
# After 3420 steps, per token cost is 3.425
# After 3430 steps, per token cost is 3.323
# After 3440 steps, per token cost is 3.376
# After 3450 steps, per token cost is 3.426
# After 3460 steps, per token cost is 3.300
# After 3470 steps, per token cost is 3.476
# After 3480 steps, per token cost is 3.225
# After 3490 steps, per token cost is 3.353
# After 3500 steps, per token cost is 3.422
# After 3510 steps, per token cost is 3.182
# After 3520 steps, per token cost is 3.335
# After 3530 steps, per token cost is 3.297
# After 3540 steps, per token cost is 3.324
# After 3550 steps, per token cost is 3.177
# After 3560 steps, per token cost is 3.369
# After 3570 steps, per token cost is 3.279
# After 3580 steps, per token cost is 3.116
# After 3590 steps, per token cost is 3.286
# After 3600 steps, per token cost is 3.253
# In iteration: 3
# After 3610 steps, per token cost is 3.493
# After 3620 steps, per token cost is 3.295
# After 3630 steps, per token cost is 3.298
# After 3640 steps, per token cost is 3.173
# After 3650 steps, per token cost is 3.251
# After 3660 steps, per token cost is 3.365
# After 3670 steps, per token cost is 3.257
# After 3680 steps, per token cost is 3.227
# After 3690 steps, per token cost is 3.377
# After 3700 steps, per token cost is 3.250
# After 3710 steps, per token cost is 3.251
# After 3720 steps, per token cost is 3.241
# After 3730 steps, per token cost is 3.309
# After 3740 steps, per token cost is 3.272
# After 3750 steps, per token cost is 3.310
# After 3760 steps, per token cost is 3.204
# After 3770 steps, per token cost is 3.193
# After 3780 steps, per token cost is 3.156
# After 3790 steps, per token cost is 3.259
# After 3800 steps, per token cost is 3.386
# After 3810 steps, per token cost is 3.293
# After 3820 steps, per token cost is 3.164
# After 3830 steps, per token cost is 3.160
# After 3840 steps, per token cost is 3.174
# After 3850 steps, per token cost is 3.222
# After 3860 steps, per token cost is 3.105
# After 3870 steps, per token cost is 3.263
# After 3880 steps, per token cost is 3.285
# After 3890 steps, per token cost is 3.167
# After 3900 steps, per token cost is 3.356
# After 3910 steps, per token cost is 3.220
# After 3920 steps, per token cost is 3.142
# After 3930 steps, per token cost is 3.141
# After 3940 steps, per token cost is 3.300
# After 3950 steps, per token cost is 3.268
# After 3960 steps, per token cost is 3.241
# After 3970 steps, per token cost is 3.195
# After 3980 steps, per token cost is 3.116
# After 3990 steps, per token cost is 3.145
# After 4000 steps, per token cost is 3.342
# After 4010 steps, per token cost is 3.196
# After 4020 steps, per token cost is 3.139
# After 4030 steps, per token cost is 3.221
# After 4040 steps, per token cost is 3.243
# After 4050 steps, per token cost is 3.311
# After 4060 steps, per token cost is 3.049
# After 4070 steps, per token cost is 2.968
# After 4080 steps, per token cost is 3.198
# After 4090 steps, per token cost is 3.049
# After 4100 steps, per token cost is 3.204
# After 4110 steps, per token cost is 3.103
# After 4120 steps, per token cost is 3.180
# After 4130 steps, per token cost is 3.116
# After 4140 steps, per token cost is 3.300
# After 4150 steps, per token cost is 3.199
# After 4160 steps, per token cost is 3.146
# After 4170 steps, per token cost is 3.259
# After 4180 steps, per token cost is 3.030
# After 4190 steps, per token cost is 3.241
# After 4200 steps, per token cost is 3.133
# After 4210 steps, per token cost is 3.114
# After 4220 steps, per token cost is 3.049
# After 4230 steps, per token cost is 3.228
# After 4240 steps, per token cost is 3.214
# After 4250 steps, per token cost is 3.232
# After 4260 steps, per token cost is 3.178
# After 4270 steps, per token cost is 3.241
# After 4280 steps, per token cost is 3.095
# After 4290 steps, per token cost is 3.077
# After 4300 steps, per token cost is 3.233
# After 4310 steps, per token cost is 3.087
# After 4320 steps, per token cost is 3.219
# After 4330 steps, per token cost is 3.237
# After 4340 steps, per token cost is 3.234
# After 4350 steps, per token cost is 3.138
# After 4360 steps, per token cost is 3.283
# After 4370 steps, per token cost is 3.080
# After 4380 steps, per token cost is 3.175
# After 4390 steps, per token cost is 2.966
# After 4400 steps, per token cost is 3.097
# After 4410 steps, per token cost is 3.114
# After 4420 steps, per token cost is 3.165
# After 4430 steps, per token cost is 3.072
# After 4440 steps, per token cost is 3.130
# After 4450 steps, per token cost is 3.057
# After 4460 steps, per token cost is 3.074
# After 4470 steps, per token cost is 2.953
# After 4480 steps, per token cost is 3.051
# After 4490 steps, per token cost is 3.089
# After 4500 steps, per token cost is 3.094
# After 4510 steps, per token cost is 3.103
# After 4520 steps, per token cost is 3.085
# After 4530 steps, per token cost is 3.056
# After 4540 steps, per token cost is 3.039
# After 4550 steps, per token cost is 3.151
# After 4560 steps, per token cost is 3.064
# After 4570 steps, per token cost is 3.040
# After 4580 steps, per token cost is 2.856
# After 4590 steps, per token cost is 3.248
# After 4600 steps, per token cost is 3.183
# After 4610 steps, per token cost is 2.940
# After 4620 steps, per token cost is 3.080
# After 4630 steps, per token cost is 3.230
# After 4640 steps, per token cost is 3.096
# After 4650 steps, per token cost is 3.137
# After 4660 steps, per token cost is 3.075
# After 4670 steps, per token cost is 2.953
# After 4680 steps, per token cost is 2.958
# After 4690 steps, per token cost is 2.966
# After 4700 steps, per token cost is 3.183
# After 4710 steps, per token cost is 3.060
# After 4720 steps, per token cost is 2.993
# After 4730 steps, per token cost is 2.959
# After 4740 steps, per token cost is 3.098
# After 4750 steps, per token cost is 3.098
# After 4760 steps, per token cost is 3.198
# After 4770 steps, per token cost is 3.095
# After 4780 steps, per token cost is 3.041
# After 4790 steps, per token cost is 3.040
# After 4800 steps, per token cost is 2.853
# After 4810 steps, per token cost is 2.984
# After 4820 steps, per token cost is 2.878
# After 4830 steps, per token cost is 2.914
# After 4840 steps, per token cost is 2.988
# After 4850 steps, per token cost is 2.975
# After 4860 steps, per token cost is 3.124
# After 4870 steps, per token cost is 2.972
# After 4880 steps, per token cost is 3.147
# After 4890 steps, per token cost is 3.029
# After 4900 steps, per token cost is 3.075
# After 4910 steps, per token cost is 2.869
# After 4920 steps, per token cost is 2.958
# After 4930 steps, per token cost is 2.836
# After 4940 steps, per token cost is 3.173
# After 4950 steps, per token cost is 2.981
# After 4960 steps, per token cost is 3.093
# After 4970 steps, per token cost is 2.995
# After 4980 steps, per token cost is 3.015
# After 4990 steps, per token cost is 3.024
# After 5000 steps, per token cost is 2.902
# After 5010 steps, per token cost is 3.050
# After 5020 steps, per token cost is 3.095
# After 5030 steps, per token cost is 2.855
# After 5040 steps, per token cost is 3.019
# After 5050 steps, per token cost is 3.046
# After 5060 steps, per token cost is 3.099
# After 5070 steps, per token cost is 2.926
# After 5080 steps, per token cost is 2.978
# After 5090 steps, per token cost is 3.043
# After 5100 steps, per token cost is 3.119
# After 5110 steps, per token cost is 3.100
# After 5120 steps, per token cost is 3.043
# After 5130 steps, per token cost is 2.890
# After 5140 steps, per token cost is 2.887
# After 5150 steps, per token cost is 2.929
# After 5160 steps, per token cost is 2.987
# After 5170 steps, per token cost is 3.007
# After 5180 steps, per token cost is 3.179
# After 5190 steps, per token cost is 3.013
# After 5200 steps, per token cost is 2.882
# After 5210 steps, per token cost is 3.062
# After 5220 steps, per token cost is 2.980
# After 5230 steps, per token cost is 2.947
# After 5240 steps, per token cost is 3.071
# After 5250 steps, per token cost is 2.905
# After 5260 steps, per token cost is 3.275
# After 5270 steps, per token cost is 2.995
# After 5280 steps, per token cost is 2.954
# After 5290 steps, per token cost is 3.122
# After 5300 steps, per token cost is 3.014
# After 5310 steps, per token cost is 2.954
# After 5320 steps, per token cost is 3.050
# After 5330 steps, per token cost is 3.081
# After 5340 steps, per token cost is 2.963
# After 5350 steps, per token cost is 3.006
# After 5360 steps, per token cost is 2.908
# After 5370 steps, per token cost is 3.003
# After 5380 steps, per token cost is 2.959
# After 5390 steps, per token cost is 3.058
# After 5400 steps, per token cost is 2.955
# In iteration: 4
# After 5410 steps, per token cost is 3.123
# After 5420 steps, per token cost is 3.006
# After 5430 steps, per token cost is 3.069
# After 5440 steps, per token cost is 2.996
# After 5450 steps, per token cost is 2.985
# After 5460 steps, per token cost is 2.944
# After 5470 steps, per token cost is 2.995
# After 5480 steps, per token cost is 2.969
# After 5490 steps, per token cost is 2.947
# After 5500 steps, per token cost is 2.882
# After 5510 steps, per token cost is 2.994
# After 5520 steps, per token cost is 2.988
# After 5530 steps, per token cost is 2.832
# After 5540 steps, per token cost is 3.078
# After 5550 steps, per token cost is 2.815
# After 5560 steps, per token cost is 2.949
# After 5570 steps, per token cost is 2.834
# After 5580 steps, per token cost is 2.975
# After 5590 steps, per token cost is 3.027
# After 5600 steps, per token cost is 2.859
# After 5610 steps, per token cost is 2.938
# After 5620 steps, per token cost is 2.843
# After 5630 steps, per token cost is 2.915
# After 5640 steps, per token cost is 2.924
# After 5650 steps, per token cost is 2.925
# After 5660 steps, per token cost is 2.925
# After 5670 steps, per token cost is 2.961
# After 5680 steps, per token cost is 2.829
# After 5690 steps, per token cost is 2.748
# After 5700 steps, per token cost is 2.774
# After 5710 steps, per token cost is 2.903
# After 5720 steps, per token cost is 2.917
# After 5730 steps, per token cost is 2.930
# After 5740 steps, per token cost is 2.870
# After 5750 steps, per token cost is 2.769
# After 5760 steps, per token cost is 2.889
# After 5770 steps, per token cost is 2.908
# After 5780 steps, per token cost is 2.866
# After 5790 steps, per token cost is 2.843
# After 5800 steps, per token cost is 2.860
# After 5810 steps, per token cost is 2.893
# After 5820 steps, per token cost is 2.817
# After 5830 steps, per token cost is 2.843
# After 5840 steps, per token cost is 2.936
# After 5850 steps, per token cost is 2.880
# After 5860 steps, per token cost is 2.865
# After 5870 steps, per token cost is 2.785
# After 5880 steps, per token cost is 2.892
# After 5890 steps, per token cost is 2.870
# After 5900 steps, per token cost is 2.794
# After 5910 steps, per token cost is 2.888
# After 5920 steps, per token cost is 2.973
# After 5930 steps, per token cost is 2.765
# After 5940 steps, per token cost is 2.963
# After 5950 steps, per token cost is 2.963
# After 5960 steps, per token cost is 2.818
# After 5970 steps, per token cost is 2.905
# After 5980 steps, per token cost is 2.762
# After 5990 steps, per token cost is 2.998
# After 6000 steps, per token cost is 2.677
# After 6010 steps, per token cost is 2.776
# After 6020 steps, per token cost is 2.913
# After 6030 steps, per token cost is 2.777
# After 6040 steps, per token cost is 2.894
# After 6050 steps, per token cost is 2.938
# After 6060 steps, per token cost is 3.056
# After 6070 steps, per token cost is 2.897
# After 6080 steps, per token cost is 2.818
# After 6090 steps, per token cost is 2.785
# After 6100 steps, per token cost is 3.010
# After 6110 steps, per token cost is 2.903
# After 6120 steps, per token cost is 2.960
# After 6130 steps, per token cost is 2.931
# After 6140 steps, per token cost is 2.880
# After 6150 steps, per token cost is 2.924
# After 6160 steps, per token cost is 2.754
# After 6170 steps, per token cost is 2.864
# After 6180 steps, per token cost is 2.910
# After 6190 steps, per token cost is 2.921
# After 6200 steps, per token cost is 2.707
# After 6210 steps, per token cost is 2.813
# After 6220 steps, per token cost is 2.815
# After 6230 steps, per token cost is 2.846
# After 6240 steps, per token cost is 2.840
# After 6250 steps, per token cost is 2.890
# After 6260 steps, per token cost is 2.785
# After 6270 steps, per token cost is 2.776
# After 6280 steps, per token cost is 2.785
# After 6290 steps, per token cost is 2.851
# After 6300 steps, per token cost is 2.656
# After 6310 steps, per token cost is 2.796
# After 6320 steps, per token cost is 2.852
# After 6330 steps, per token cost is 2.696
# After 6340 steps, per token cost is 2.721
# After 6350 steps, per token cost is 2.875
# After 6360 steps, per token cost is 2.950
# After 6370 steps, per token cost is 2.844
# After 6380 steps, per token cost is 2.819
# After 6390 steps, per token cost is 2.836
# After 6400 steps, per token cost is 2.846
# After 6410 steps, per token cost is 2.782
# After 6420 steps, per token cost is 2.873
# After 6430 steps, per token cost is 2.792
# After 6440 steps, per token cost is 2.752
# After 6450 steps, per token cost is 2.792
# After 6460 steps, per token cost is 2.938
# After 6470 steps, per token cost is 2.768
# After 6480 steps, per token cost is 2.913
# After 6490 steps, per token cost is 2.811
# After 6500 steps, per token cost is 2.804
# After 6510 steps, per token cost is 2.813
# After 6520 steps, per token cost is 2.859
# After 6530 steps, per token cost is 2.730
# After 6540 steps, per token cost is 2.783
# After 6550 steps, per token cost is 2.669
# After 6560 steps, per token cost is 2.965
# After 6570 steps, per token cost is 2.890
# After 6580 steps, per token cost is 2.777
# After 6590 steps, per token cost is 2.723
# After 6600 steps, per token cost is 2.722
# After 6610 steps, per token cost is 2.907
# After 6620 steps, per token cost is 2.728
# After 6630 steps, per token cost is 2.750
# After 6640 steps, per token cost is 2.695
# After 6650 steps, per token cost is 2.812
# After 6660 steps, per token cost is 2.682
# After 6670 steps, per token cost is 2.731
# After 6680 steps, per token cost is 2.726
# After 6690 steps, per token cost is 2.749
# After 6700 steps, per token cost is 2.809
# After 6710 steps, per token cost is 2.878
# After 6720 steps, per token cost is 2.817
# After 6730 steps, per token cost is 2.809
# After 6740 steps, per token cost is 2.747
# After 6750 steps, per token cost is 2.742
# After 6760 steps, per token cost is 2.855
# After 6770 steps, per token cost is 2.807
# After 6780 steps, per token cost is 2.853
# After 6790 steps, per token cost is 2.559
# After 6800 steps, per token cost is 2.687
# After 6810 steps, per token cost is 2.759
# After 6820 steps, per token cost is 2.700
# After 6830 steps, per token cost is 2.751
# After 6840 steps, per token cost is 2.816
# After 6850 steps, per token cost is 2.729
# After 6860 steps, per token cost is 2.855
# After 6870 steps, per token cost is 2.871
# After 6880 steps, per token cost is 2.962
# After 6890 steps, per token cost is 2.672
# After 6900 steps, per token cost is 2.942
# After 6910 steps, per token cost is 2.778
# After 6920 steps, per token cost is 2.731
# After 6930 steps, per token cost is 2.802
# After 6940 steps, per token cost is 2.819
# After 6950 steps, per token cost is 2.664
# After 6960 steps, per token cost is 2.692
# After 6970 steps, per token cost is 2.741
# After 6980 steps, per token cost is 2.656
# After 6990 steps, per token cost is 2.783
# After 7000 steps, per token cost is 2.638
# After 7010 steps, per token cost is 2.817
# After 7020 steps, per token cost is 2.831
# After 7030 steps, per token cost is 2.833
# After 7040 steps, per token cost is 2.722
# After 7050 steps, per token cost is 2.698
# After 7060 steps, per token cost is 2.754
# After 7070 steps, per token cost is 2.851
# After 7080 steps, per token cost is 2.781
# After 7090 steps, per token cost is 2.758
# After 7100 steps, per token cost is 2.847
# After 7110 steps, per token cost is 2.824
# After 7120 steps, per token cost is 2.640
# After 7130 steps, per token cost is 2.782
# After 7140 steps, per token cost is 2.600
# After 7150 steps, per token cost is 2.742
# After 7160 steps, per token cost is 2.762
# After 7170 steps, per token cost is 2.691
# After 7180 steps, per token cost is 2.792
# After 7190 steps, per token cost is 2.697
# After 7200 steps, per token cost is 2.714
# After 7210 steps, per token cost is 2.811
# In iteration: 5
# After 7220 steps, per token cost is 2.769
# After 7230 steps, per token cost is 2.799
# After 7240 steps, per token cost is 2.748
# After 7250 steps, per token cost is 2.586
# After 7260 steps, per token cost is 2.803
# After 7270 steps, per token cost is 2.787
# After 7280 steps, per token cost is 2.834
# After 7290 steps, per token cost is 2.696
# After 7300 steps, per token cost is 2.801
# After 7310 steps, per token cost is 2.661
# After 7320 steps, per token cost is 2.633
# After 7330 steps, per token cost is 2.751
# After 7340 steps, per token cost is 2.840
# After 7350 steps, per token cost is 2.668
# After 7360 steps, per token cost is 2.624
# After 7370 steps, per token cost is 2.521
# After 7380 steps, per token cost is 2.716
# After 7390 steps, per token cost is 2.738
# After 7400 steps, per token cost is 2.657
# After 7410 steps, per token cost is 2.579
# After 7420 steps, per token cost is 2.655
# After 7430 steps, per token cost is 2.670
# After 7440 steps, per token cost is 2.670
# After 7450 steps, per token cost is 2.728
# After 7460 steps, per token cost is 2.672
# After 7470 steps, per token cost is 2.681
# After 7480 steps, per token cost is 2.659
# After 7490 steps, per token cost is 2.708
# After 7500 steps, per token cost is 2.697
# After 7510 steps, per token cost is 2.699
# After 7520 steps, per token cost is 2.559
# After 7530 steps, per token cost is 2.674
# After 7540 steps, per token cost is 2.737
# After 7550 steps, per token cost is 2.748
# After 7560 steps, per token cost is 2.682
# After 7570 steps, per token cost is 2.813
# After 7580 steps, per token cost is 2.697
# After 7590 steps, per token cost is 2.771
# After 7600 steps, per token cost is 2.779
# After 7610 steps, per token cost is 2.533
# After 7620 steps, per token cost is 2.683
# After 7630 steps, per token cost is 2.693
# After 7640 steps, per token cost is 2.661
# After 7650 steps, per token cost is 2.780
# After 7660 steps, per token cost is 2.690
# After 7670 steps, per token cost is 2.683
# After 7680 steps, per token cost is 2.608
# After 7690 steps, per token cost is 2.709
# After 7700 steps, per token cost is 2.708
# After 7710 steps, per token cost is 2.624
# After 7720 steps, per token cost is 2.658
# After 7730 steps, per token cost is 2.756
# After 7740 steps, per token cost is 2.713
# After 7750 steps, per token cost is 2.664
# After 7760 steps, per token cost is 2.562
# After 7770 steps, per token cost is 2.676
# After 7780 steps, per token cost is 2.633
# After 7790 steps, per token cost is 2.595
# After 7800 steps, per token cost is 2.695
# After 7810 steps, per token cost is 2.679
# After 7820 steps, per token cost is 2.683
# After 7830 steps, per token cost is 2.716
# After 7840 steps, per token cost is 2.679
# After 7850 steps, per token cost is 2.701
# After 7860 steps, per token cost is 2.653
# After 7870 steps, per token cost is 2.693
# After 7880 steps, per token cost is 2.668
# After 7890 steps, per token cost is 2.749
# After 7900 steps, per token cost is 2.677
# After 7910 steps, per token cost is 2.770
# After 7920 steps, per token cost is 2.819
# After 7930 steps, per token cost is 2.873
# After 7940 steps, per token cost is 2.660
# After 7950 steps, per token cost is 2.628
# After 7960 steps, per token cost is 2.563
# After 7970 steps, per token cost is 2.722
# After 7980 steps, per token cost is 2.864
# After 7990 steps, per token cost is 2.625
# After 8000 steps, per token cost is 2.625
# After 8010 steps, per token cost is 2.600
# After 8020 steps, per token cost is 2.785
# After 8030 steps, per token cost is 2.565
# After 8040 steps, per token cost is 2.659
# After 8050 steps, per token cost is 2.649
# After 8060 steps, per token cost is 2.506
# After 8070 steps, per token cost is 2.660
# After 8080 steps, per token cost is 2.635
# After 8090 steps, per token cost is 2.677
# After 8100 steps, per token cost is 2.608
# After 8110 steps, per token cost is 2.625
# After 8120 steps, per token cost is 2.509
# After 8130 steps, per token cost is 2.520
# After 8140 steps, per token cost is 2.620
# After 8150 steps, per token cost is 2.463
# After 8160 steps, per token cost is 2.665
# After 8170 steps, per token cost is 2.657
# After 8180 steps, per token cost is 2.562
# After 8190 steps, per token cost is 2.523
# After 8200 steps, per token cost is 2.430
# After 8210 steps, per token cost is 2.586
# After 8220 steps, per token cost is 2.620
# After 8230 steps, per token cost is 2.684
# After 8240 steps, per token cost is 2.525
# After 8250 steps, per token cost is 2.645
# After 8260 steps, per token cost is 2.557
# After 8270 steps, per token cost is 2.582
# After 8280 steps, per token cost is 2.595
# After 8290 steps, per token cost is 2.669
# After 8300 steps, per token cost is 2.655
# After 8310 steps, per token cost is 2.660
# After 8320 steps, per token cost is 2.668
# After 8330 steps, per token cost is 2.647
# After 8340 steps, per token cost is 2.628
# After 8350 steps, per token cost is 2.750
# After 8360 steps, per token cost is 2.677
# After 8370 steps, per token cost is 2.620
# After 8380 steps, per token cost is 2.638
# After 8390 steps, per token cost is 2.478
# After 8400 steps, per token cost is 2.497
# After 8410 steps, per token cost is 2.550
# After 8420 steps, per token cost is 2.686
# After 8430 steps, per token cost is 2.518
# After 8440 steps, per token cost is 2.521
# After 8450 steps, per token cost is 2.587
# After 8460 steps, per token cost is 2.509
# After 8470 steps, per token cost is 2.663
# After 8480 steps, per token cost is 2.597
# After 8490 steps, per token cost is 2.720
# After 8500 steps, per token cost is 2.567
# After 8510 steps, per token cost is 2.603
# After 8520 steps, per token cost is 2.528
# After 8530 steps, per token cost is 2.553
# After 8540 steps, per token cost is 2.718
# After 8550 steps, per token cost is 2.446
# After 8560 steps, per token cost is 2.522
# After 8570 steps, per token cost is 2.500
# After 8580 steps, per token cost is 2.519
# After 8590 steps, per token cost is 2.520
# After 8600 steps, per token cost is 2.660
# After 8610 steps, per token cost is 2.440
# After 8620 steps, per token cost is 2.493
# After 8630 steps, per token cost is 2.627
# After 8640 steps, per token cost is 2.600
# After 8650 steps, per token cost is 2.626
# After 8660 steps, per token cost is 2.591
# After 8670 steps, per token cost is 2.544
# After 8680 steps, per token cost is 2.641
# After 8690 steps, per token cost is 2.605
# After 8700 steps, per token cost is 2.605
# After 8710 steps, per token cost is 2.688
# After 8720 steps, per token cost is 2.737
# After 8730 steps, per token cost is 2.779
# After 8740 steps, per token cost is 2.627
# After 8750 steps, per token cost is 2.602
# After 8760 steps, per token cost is 2.706
# After 8770 steps, per token cost is 2.485
# After 8780 steps, per token cost is 2.551
# After 8790 steps, per token cost is 2.456
# After 8800 steps, per token cost is 2.617
# After 8810 steps, per token cost is 2.680
# After 8820 steps, per token cost is 2.581
# After 8830 steps, per token cost is 2.559
# After 8840 steps, per token cost is 2.523
# After 8850 steps, per token cost is 2.721
# After 8860 steps, per token cost is 2.636
# After 8870 steps, per token cost is 2.611
# After 8880 steps, per token cost is 2.589
# After 8890 steps, per token cost is 2.547
# After 8900 steps, per token cost is 2.653
# After 8910 steps, per token cost is 2.531
# After 8920 steps, per token cost is 2.562
# After 8930 steps, per token cost is 2.576
# After 8940 steps, per token cost is 2.564
# After 8950 steps, per token cost is 2.484
# After 8960 steps, per token cost is 2.506
# After 8970 steps, per token cost is 2.625
# After 8980 steps, per token cost is 2.450
# After 8990 steps, per token cost is 2.531
# After 9000 steps, per token cost is 2.483
# After 9010 steps, per token cost is 2.653
